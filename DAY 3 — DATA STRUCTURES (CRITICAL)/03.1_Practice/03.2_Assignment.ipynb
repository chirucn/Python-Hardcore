# %%
#A-1: Average Calculator
def average(prices):
    return sum(prices)/len(prices)

prices = [19500, 19600, 19700]
print(average(prices))
# Out:
# 19600.0

# %%
#A-2: Minimum Number finder
def mini_num(prices):
    min_num=prices[0]
    for p in prices:
        if p<min_num:
            min_num=p
    return min_num

prices=[100, 101,98]
mini_num(prices)
# Out:
# 98

# %%
#A-3: Count Even Numbers in aa list
def count_even(nums):
    count=0
    for i in nums:
        if i%2==0:
            count+=1
    return count

nums=[1,2,3,4,5,6]
count_even(nums)
# Out:
# 3

# %%
#A-5: Trade PnL Calculator
def trade_pnl(trades3):
    total_pnl = 0
    for trade in trades3:
        total_pnl += (trade["Exit"] - trade["Entry"]) * trade["Qty"]
    return total_pnl

trades3=[
    {"Entry": 25000, "Exit": 25100, "Qty": 65},
    {"Entry": 35000, "Exit": 34900, "Qty": 35}
]
trade_pnl(trades3)
# Out:
# 3000

# %%
#A-4: Trade Logger
trades4={{"Symbol":"NIFTY", "Price":25000, "Qty":65},
        {"Symbol":"BANKNIFTY", "Price":35000, "Qty":35}
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #A-4: Trade Logger
# ----> 2 trades4={{"Symbol":"NIFTY", "Price":25000, "Qty":65},
#       3         {"Symbol":"BANKNIFTY", "Price":35000, "Qty":35}
#       4 }
#
# TypeError: cannot use 'dict' as a set element (unhashable type: 'dict')
