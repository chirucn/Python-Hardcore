# %%
#1.First Program
print("Hello, World!!")
# Out:
# Hello, World!!

# %%
#2.Variables(Core Concepts)
x=10
y=20
print(x+y)

a=5
b=15
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 30
# 20
# -10
# 75
# 0.3333333333333333

# %%
#3.Data Types(Very Important)
x1=15 #int
x2=5.14 #float
name="Chiru" #String
is_active=True #Boolean
#Type Checking
print(type(x2))
# Out:
# <class 'float'>

# %%
#4.User Input(interaction)
age = input("Enter age: ")
age = int(age)
print(age + age)
# Out:
# 44

# %%
#5.Conditions(Decision Making)
age1=int(input("Enter your age:"))
if age1 >=18:
    print("You can trade")
else:
    print("You cannot underage")
# Out:
# You can trade

# %%
#6.Loops(Repetition)
#for loop
for i in  range(5):
    print(i)
print()
#while loop
c=0
while c<5:
    print(c)
    c+=2
# Out:
# 0
# 1
# 2
# 3
# 4
#
# 0
# 2
# 4
